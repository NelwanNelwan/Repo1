# %%
import pandas

# %%
df=pandas.read_csv('../data/merged_data.csv',index_col=5)
df=df.rename(index={'Post code': 'PostCode'})
df
# Out:
#           TEAM_CODE    TEAM_NAME TERRITORY_NAME  \
# Post code
# 2263         RGP004  Diabetes GP      RGP004201
# 2285         RGP004  Diabetes GP      RGP004201
# 2323         RGP004  Diabetes GP      RGP004201
# 2280         RGP004  Diabetes GP      RGP004201
# 2440         RGP004  Diabetes GP      RGP004201
# 2323         RGP004  Diabetes GP      RGP004201
# 2440         RGP004  Diabetes GP      RGP004201
# 2250         RGP004  Diabetes GP      RGP004201
# 2258         RGP004  Diabetes GP      RGP004201
# 2263         RGP004  Diabetes GP      RGP004201
# 2250         RGP004  Diabetes GP      RGP004201
# 2280         RGP004  Diabetes GP      RGP004201
# 2264         RGP004  Diabetes GP      RGP004201
# 2263         RGP004  Diabetes GP      RGP004201
# 2440         RGP004  Diabetes GP      RGP004201
# 2280         RGP004  Diabetes GP      RGP004201
# 2444         RGP004  Diabetes GP      RGP004201
# 2265         RGP004  Diabetes GP      RGP004201
# ...

# %%
df.describe()
# Out:
#        People Diagnosed       Type 2  Census Population  Unnamed: 10
# count       7957.000000  7957.000000        7957.000000          0.0
# mean        1809.747141  1582.151313       31467.437728          NaN
# std         1357.536169  1196.680662       21821.724948          NaN
# min           16.000000    14.000000          82.000000          NaN
# 25%          818.000000   696.000000       15458.000000          NaN
# 50%         1494.000000  1315.000000       26611.000000          NaN
# 75%         2339.000000  2031.000000       42291.000000          NaN
# max         7459.000000  6441.000000      117954.000000          NaN

# %%
df.corr()
# Out:
#                    People Diagnosed    Type 2  Census Population  Unnamed: 10
# People Diagnosed           1.000000  0.999206           0.952736          NaN
# Type 2                     0.999206  1.000000           0.945842          NaN
# Census Population          0.952736  0.945842           1.000000          NaN
# Unnamed: 10                     NaN       NaN                NaN          NaN
