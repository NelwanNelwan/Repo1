# %%
# %matplotlib inline
import pandas
sacramento = pandas.read_csv('../../SYD_DAT_7/data/Sacramento-real-estate-transactions.csv')
sacramento
# Out:
#                               street             city    zip state  beds  \
# 0                       3526 HIGH ST       SACRAMENTO  95838    CA     2
# 1                        51 OMAHA CT       SACRAMENTO  95823    CA     3
# 2                     2796 BRANCH ST       SACRAMENTO  95815    CA     2
# 3                   2805 JANETTE WAY       SACRAMENTO  95815    CA     2
# 4                    6001 MCMAHON DR       SACRAMENTO  95824    CA     2
# 5                 5828 PEPPERMILL CT       SACRAMENTO  95841    CA     3
# 6                6048 OGDEN NASH WAY       SACRAMENTO  95842    CA     3
# 7                      2561 19TH AVE       SACRAMENTO  95820    CA     3
# 8    11150 TRINITY RIVER DR Unit 114   RANCHO CORDOVA  95670    CA     2
# 9                       7325 10TH ST        RIO LINDA  95673    CA     3
# 10                  645 MORRISON AVE       SACRAMENTO  95838    CA     3
# 11                     4085 FAWN CIR       SACRAMENTO  95823    CA     3
# ...

# %%
sacramento.price.plot()

# %%
sacramento.price.head(5)
# Out:
# 0    59222
# 1    68212
# 2    68880
# 3    69307
# 4    81900
# Name: price, dtype: int64

# %%
sacramento.price.head(5).plot()

# %%
pandas.to_datetime(sacramento.sale_date)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-4a086f621769> in <module>()
# ----> 1 pandas.to_datetime(sacramento.sale_date).plot()
#
# /Applications/anaconda/lib/python2.7/site-packages/pandas/tools/plotting.pyc in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    3598                            colormap=colormap, table=table, yerr=yerr,
#    3599                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 3600                            **kwds)
#    3601     __call__.__doc__ = plot_series.__doc__
#    3602
#
# ...

# %%
sacramento['clean_date']= pandas.to_datetime(sacramento.sale_date)

# %%
sacramento.clean_date.dt.dayofyear
# Out:
# 0      142
# 1      142
# 2      142
# 3      142
# 4      142
# 5      142
# 6      142
# 7      142
# 8      142
# 9      142
# 10     142
# 11     142
# 12     142
# 13     142
# 14     142
# 15     142
# 16     142
# 17     142
# 18     142
# 19     142
# 20     142
# 21     142
# 22     142
# 23     142
# 24     142
# 25     142
# 26     142
# 27     142
# 28     142
# 29     142
#       ...
# 955    136
# 956    136
# 957    136
# 958    136
# 959    136
# 960    136
# 961    136
# 962    136
# 963    136
# 964    136
# 965    136
# 966    136
# 967    136
# 968    136
# 969    136
# 970    136
# 971    136
# 972    136
# 973    136
# 974    136
# 975    136
# 976    136
# 977    136
# 978    136
# 979    136
# 980    136
# 981    136
# 982    136
# 983    136
# 984    136
# Name: clean_date, dtype: int64

# %%
sacramento.clean_date.dt.dayofyear.plot()

# %%
sacramento.price.sort_values()
# Out:
# 865      1551
# 866      2000
# 580      4897
# 584      4897
# 585      4897
# 586      4897
# 587      4897
# 588      4897
# 589      4897
# 590      4897
# 591      4897
# 592      4897
# 593      4897
# 594      4897
# 595      4897
# 596      4897
# 597      4897
# 598      4897
# 599      4897
# 600      4897
# 601      4897
# 602      4897
# 579      4897
# 582      4897
# 581      4897
# 583      4897
# 555      4897
# 578      4897
# 577      4897
# 576      4897
#         ...
# 854    575000
# 853    575000
# 547    579093
# 329    582000
# 153    585000
# 855    598695
# 858    600000
# 857    600000
# 859    600000
# 856    600000
# 154    600000
# 155    606238
# 860    610000
# 330    613401
# 331    614000
# 861    622500
# 548    636000
# 156    660000
# 549    668365
# 550    676200
# 551    677048
# 862    680000
# 332    680000
# 552    691659
# 333    699000
# 553    760000
# 157    830000
# 334    839000
# 863    879000
# 864    884790
# ...

# %%
sacramento.price.sort_values().plot()

# %%
sacramento.price.sort_values().head(10).plot()

# %%
sacramento.price.sample(10).sort_values().plot()

# %%
list(sacramento.price.sort_values())
# Out:
# [1551,
#  2000,
#  4897,
#  4897,
#  4897,
#  4897,
#  4897,
#  4897,
#  4897,
#  4897,
#  4897,
#  4897,
#  4897,
#  4897,
#  4897,
#  4897,
#  4897,
#  4897,
#  4897,
#  4897,
#  4897,
#  4897,
#  4897,
#  4897,
#  4897,
#  4897,
#  4897,
#  4897,
#  4897,
#  4897,
#  4897,
#  4897,
#  4897,
#  4897,
#  4897,
#  4897,
#  4897,
#  4897,
#  4897,
#  4897,
#  4897,
#  4897,
#  4897,
#  4897,
#  4897,
#  4897,
#  4897,
#  4897,
#  4897,
#  4897,
#  4897,
#  30000,
#  30000,
#  40000,
#  48000,
#  55422,
#  56950,
#  59222,
#  60000,
#  61000,
#  61500,
#  62000,
#  62050,
#  63000,
#  65000,
#  65000,
#  65000,
#  65000,
#  65000,
#  66500,
#  68000,
#  68000,
#  68212,
#  68566,
#  68880,
#  69000,
#  69307,
#  70000,
#  70000,
#  71000,
#  71000,
#  75000,
#  77000,
#  77000,
#  78000,
#  78400,
#  80000,
#  80000,
#  81900,
#  82732,
#  84000,
#  84675,
#  85000,
#  85000,
#  85500,
#  89000,
#  89921,
#  90000,
#  90000,
#  90000,
#  90000,
#  90895,
#  91000,
#  91002,
#  92000,
# ...

# %%
#list is to take out the index
pricing_data= pandas.Series(list(sacramento.price.sort_values()))
pricing_data
# Out:
# 0        1551
# 1        2000
# 2        4897
# 3        4897
# 4        4897
# 5        4897
# 6        4897
# 7        4897
# 8        4897
# 9        4897
# 10       4897
# 11       4897
# 12       4897
# 13       4897
# 14       4897
# 15       4897
# 16       4897
# 17       4897
# 18       4897
# 19       4897
# 20       4897
# 21       4897
# 22       4897
# 23       4897
# 24       4897
# 25       4897
# 26       4897
# 27       4897
# 28       4897
# 29       4897
#         ...
# 955    575000
# 956    575000
# 957    579093
# 958    582000
# 959    585000
# 960    598695
# 961    600000
# 962    600000
# 963    600000
# 964    600000
# 965    600000
# 966    606238
# 967    610000
# 968    613401
# 969    614000
# 970    622500
# 971    636000
# 972    660000
# 973    668365
# 974    676200
# 975    677048
# 976    680000
# 977    680000
# 978    691659
# 979    699000
# 980    760000
# 981    830000
# 982    839000
# 983    879000
# 984    884790
# dtype: int64

# %%
pricing_data.plot()

# %%
pricing_data.head(10).plot()

# %%
pricing_data.tail(10).plot()

# %%
sacramento.set_index('clean_date')
# Out:
#                                      street             city    zip state  \
# clean_date
# 2008-05-21                     3526 HIGH ST       SACRAMENTO  95838    CA
# 2008-05-21                      51 OMAHA CT       SACRAMENTO  95823    CA
# 2008-05-21                   2796 BRANCH ST       SACRAMENTO  95815    CA
# 2008-05-21                 2805 JANETTE WAY       SACRAMENTO  95815    CA
# 2008-05-21                  6001 MCMAHON DR       SACRAMENTO  95824    CA
# 2008-05-21               5828 PEPPERMILL CT       SACRAMENTO  95841    CA
# 2008-05-21              6048 OGDEN NASH WAY       SACRAMENTO  95842    CA
# 2008-05-21                    2561 19TH AVE       SACRAMENTO  95820    CA
# 2008-05-21  11150 TRINITY RIVER DR Unit 114   RANCHO CORDOVA  95670    CA
# 2008-05-21                     7325 10TH ST        RIO LINDA  95673    CA
# 2008-05-21                 645 MORRISON AVE       SACRAMENTO  95838    CA
# ...

# %%
sacramento.price.nsmallest(10).plot.bar()

# %% [markdown]
# sacramento.set_index('street').nsmallest(10).plot()

# %%
sacramento.set_index('street').price.nsmallest(10).plot()

# %%
sacramento.set_index('street').price.nsmallest(10).plot.bar()

# %%
sacramento.price.plot.hist()

# %%
(sacramento.price/1000.0).plot.hist()

# %%
(sacramento.price/1000.0).plot.hist(bins=5)

# %%
sacramento.plot.scatter('longitude', 'latitude')

# %%
def bed_colours (beds):
    if beds == 1:return 'red'
    if beds == 2:return 'green'
    if beds == 3:return 'blue'
    return 'pink'

# %%
sacramento.plot.scatter('longitude', 'latitude', c=sacramento.beds.map(bed_colours))

# %%
import matplotlib.pyplot
sacramento.plot.scatter('longitude', 'latitude', c=sacramento.baths, colormap=matplotlib.pyplot.cm.inferno)

# %%
sacramento.plot.scatter('longitude', 'latitude', c=sacramento.price, colormap=matplotlib.pyplot.cm.PuBu)

# %%
sacramento.plot.scatter('longitude', 'latitude', c=sacramento.price, colormap=matplotlib.pyplot.cm.PuBu, s=sacramento.beds)

# %%
sacramento.plot.scatter('longitude', 'latitude', c=sacramento.price, colormap=matplotlib.pyplot.cm.PuBu, s=sacramento.beds*50)

# %%
sacramento.type.unique()
# Out:
# array(['Residential', 'Condo', 'Multi-Family', 'Unkown'], dtype=object)

# %%
big_houses.plot.scatter('latitude', 'longitude', 
                        c=big_houses.price, 
                        colormap=matplotlib.pyplot.cm.rainbow, 
                        s=big_houses.beds*50)

# %%
sacramento.type.unique()
# Out:
# array(['Residential', 'Condo', 'Multi-Family', 'Unkown'], dtype=object)

# %%
sacramento['sale_day_of_year'] = sacramento.clean_date.dt.dayofyear

# %%
residential = sacramento[sacramento.type == 'Residential']
condo = sacramento[sacramento.type == 'Condo']

# %%
(fig, ax) = matplotlib.pyplot.subplots()
ax.plot(residential.groupby('sale_day_of_year').price.max(),
        c='green', label='Residential', marker="o")
ax.plot(condo.groupby('sale_day_of_year').price.max(),
        c='magenta', label='Condo', marker="^", linestyle="--")
ax.set_xlabel("Day of the year")
ax.set_ylabel("Price in ($)")
ax.legend(loc='right')

# %%
import seaborn

# %%
seaborn.distplot(sacramento.price, kde=False)

# %%
seaborn.distplot(sacramento.price, kde=True)

# %%
seaborn.jointplot(data=sacramento,x='sq__ft',y='price')

# %%
seaborn.jointplot(data=sacramento,x='sq__ft',y='price', kind='kde')

# %%
seaborn.pairplot(sacramento)

# %%
seaborn.stripplot(x='type',y='price',data=sacramento, jitter=True)

# %%
seaborn.stripplot(x='zip',y='price',data=sacramento, jitter=True)

# %%
seaborn.stripplot(x='type',y='zip',data=sacramento, jitter=0.7)

# %%
seaborn.violinplot(x='type',y='zip',data=sacramento)
