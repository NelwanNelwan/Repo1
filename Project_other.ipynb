# %%
import pandas

# %%
ndss = pandas.read_csv('../data/NDSS_data.csv',index_col=0
                    )
ndss
# Out:
#           People Diagnosed  Census Population  Type 1  Type 1 %  Type 2  \
# PostCode
# 2465                    25                400       4  0.160000      21
# 2402                   152               2144      10  0.065789     142
# 2824                   211               2604      19  0.090047     188
# 2752                   240               5239      25  0.104166     205
# 2464                   519               7488      54  0.104046     459
# 2018                   874              17257      89  0.101830     735
# 2326                   501               8036      47  0.093812     446
# 2026                   846              34066     173  0.204491     619
# 2747                  2557              38384     289  0.113023    2162
# 2295                   451               6525      53  0.117516     393
# 2281                   884              15036      98  0.110859     769
# 2576                   637              14243      70  0.109890     536
# ...

# %%
poa = pandas.read_csv('../data/POA list_Diabetes.csv', index_col=5)
poa
# Out:
#           TEAM_CODE    TEAM_NAME TERRITORY_NAME  \
# Post code
# 2263         RGP004  Diabetes GP      RGP004201
# 2285         RGP004  Diabetes GP      RGP004201
# 2323         RGP004  Diabetes GP      RGP004201
# 2280         RGP004  Diabetes GP      RGP004201
# 2440         RGP004  Diabetes GP      RGP004201
# 2323         RGP004  Diabetes GP      RGP004201
# 2440         RGP004  Diabetes GP      RGP004201
# 2250         RGP004  Diabetes GP      RGP004201
# 2258         RGP004  Diabetes GP      RGP004201
# 2263         RGP004  Diabetes GP      RGP004201
# 2250         RGP004  Diabetes GP      RGP004201
# 2280         RGP004  Diabetes GP      RGP004201
# 2264         RGP004  Diabetes GP      RGP004201
# 2263         RGP004  Diabetes GP      RGP004201
# 2440         RGP004  Diabetes GP      RGP004201
# 2280         RGP004  Diabetes GP      RGP004201
# 2444         RGP004  Diabetes GP      RGP004201
# 2265         RGP004  Diabetes GP      RGP004201
# ...

# %%
data =[ndss,poa]
df = pandas.concat(data, axis=0)
df
# Out:
#       Census Population  Gestational  Gestational %  \
# 2465              400.0          0.0       0.000000
# 2402             2144.0          0.0       0.000000
# 2824             2604.0          2.0       0.009478
# 2752             5239.0          7.0       0.029166
# 2464             7488.0          4.0       0.007707
# 2018            17257.0         44.0       0.050343
# 2326             8036.0          6.0       0.011976
# 2026            34066.0         42.0       0.049645
# 2747            38384.0         91.0       0.035588
# 2295             6525.0          2.0       0.004434
# 2281            15036.0         12.0       0.013574
# 2576            14243.0         24.0       0.037676
# 2320            32828.0         59.0       0.031909
# 2663             5130.0          4.0       0.012578
# 2035            37247.0         49.0       0.034507
# 2505             5507.0         12.0       0.026200
# 2571            11366.0         18.0       0.039130
# ...

# %%
ndss.loc[[2259]]
# Out:
#           People Diagnosed  Census Population  Type 1  Type 1 %  Type 2  \
# PostCode
# 2259                  3719              60517     375  0.100833    3268
#
#           Type 2 %  Gestational  Gestational %  Other   Other %
# PostCode
# 2259       0.87873           62       0.016671     14  0.003764

# %%
poa.loc['2259']
# Out:
#           TEAM_CODE    TEAM_NAME TERRITORY_NAME  \
# Post code
# 2259         RGP004  Diabetes GP      RGP004203
# 2259         RGP004  Diabetes GP      RGP004203
# 2259         RGP004  Diabetes GP      RGP004203
# 2259         RGP004  Diabetes GP      RGP004203
# 2259         RGP004  Diabetes GP      RGP004203
# 2259         RGP004  Diabetes GP      RGP004203
# 2259         RGP004  Diabetes GP      RGP004203
# 2259         RGP004  Diabetes GP      RGP004203
# 2259         RGP004  Diabetes GP      RGP004203
# 2259         RGP004  Diabetes GP      RGP004203
# 2259         RGP004  Diabetes GP      RGP004203
# 2259         RGP004  Diabetes GP      RGP004203
# 2259         RGP004  Diabetes GP      RGP004203
# 2259         RGP004  Diabetes GP      RGP004203
# 2259         RGP004  Diabetes GP      RGP004203
# 2259         RGP004  Diabetes GP      RGP004203
# 2259         RGP004  Diabetes GP      RGP004203
# 2259         RGP004  Diabetes GP      RGP004203
# ...

# %%
df= ndss.merge(poa, how='outer', left_index=True, right_index=True)

# %%
df.loc['2259']
# Out:
#       People Diagnosed  Census Population  Type 1  Type 1 %  Type 2  Type 2 %  \
# 2259               NaN                NaN     NaN       NaN     NaN       NaN
# 2259               NaN                NaN     NaN       NaN     NaN       NaN
# 2259               NaN                NaN     NaN       NaN     NaN       NaN
# 2259               NaN                NaN     NaN       NaN     NaN       NaN
# 2259               NaN                NaN     NaN       NaN     NaN       NaN
# 2259               NaN                NaN     NaN       NaN     NaN       NaN
# 2259               NaN                NaN     NaN       NaN     NaN       NaN
# 2259               NaN                NaN     NaN       NaN     NaN       NaN
# 2259               NaN                NaN     NaN       NaN     NaN       NaN
# 2259               NaN                NaN     NaN       NaN     NaN       NaN
# 2259               NaN                NaN     NaN       NaN     NaN       NaN
# ...
